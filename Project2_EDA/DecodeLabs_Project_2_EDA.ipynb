# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Cleaned_Dataset.xlsx")

# %%
df.head()
# Out:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice  Unnamed: 14  Unnamed: 15  \
# 0     SAVE10      Instagram     2853.10          NaN          NaN
# ...

# %%
df = df.iloc[:, :14]

# %%
df.columns
# Out:
# Index(['OrderID', 'Date', 'CustomerID', 'Product', 'Quantity', 'UnitPrice',
#        'ShippingAddress', 'PaymentMethod', 'OrderStatus', 'TrackingNumber',
#        'ItemsInCart', 'CouponCode', 'ReferralSource', 'TotalPrice'],
#       dtype='str')

# %%
df.head()
# Out:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
df.shape
# Out:
# (1200, 14)

# %%
df.isnull().sum()
# Out:
# OrderID            0
# Date               0
# CustomerID         0
# Product            0
# Quantity           0
# UnitPrice          0
# ShippingAddress    0
# PaymentMethod      0
# OrderStatus        0
# TrackingNumber     0
# ItemsInCart        0
# CouponCode         0
# ReferralSource     0
# TotalPrice         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# OrderID            1200
# Date                671
# CustomerID         1189
# Product               7
# Quantity              5
# UnitPrice          1193
# ShippingAddress     655
# PaymentMethod         5
# OrderStatus           5
# TrackingNumber     1200
# ItemsInCart          10
# CouponCode            4
# ReferralSource        5
# TotalPrice         1195
# dtype: int64

# %%
df.describe()
# Out:
#                       Date     Quantity    UnitPrice  ItemsInCart   TotalPrice
# count                 1200  1200.000000  1200.000000  1200.000000  1200.000000
# mean   2024-03-22 16:58:48     2.945833   356.412750     5.485000  1053.968300
# min    2023-01-01 00:00:00     1.000000    11.390000     1.000000    11.390000
# 25%    2023-08-03 18:00:00     2.000000   186.062500     4.000000   410.520000
# 50%    2024-03-23 00:00:00     3.000000   364.210000     5.000000   823.615000
# 75%    2024-11-08 12:00:00     4.000000   521.570000     7.000000  1578.475000
# max    2025-06-30 00:00:00     5.000000   699.930000    10.000000  3456.400000
# std                    NaN     1.407557   197.177146     2.281983   819.856558

# %%
df['Product'].value_counts()
# Out:
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %%
df['OrderStatus'].value_counts()
# Out:
# OrderStatus
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64

# %%
df['CouponCode'].value_counts()
# Out:
# CouponCode
# FREESHIP     313
# NO COUPON    309
# WINTER15     292
# SAVE10       286
# Name: count, dtype: int64

# %%
df['ReferralSource'].value_counts()
# Out:
# ReferralSource
# Instagram    259
# Email        250
# Google       241
# Facebook     228
# Referral     222
# Name: count, dtype: int64

# %%
df['Quantity'].describe()
# Out:
# count    1200.000000
# mean        2.945833
# std         1.407557
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Quantity, dtype: float64

# %%
df['UnitPrice'].describe()
# Out:
# count    1200.000000
# mean      356.412750
# std       197.177146
# min        11.390000
# 25%       186.062500
# 50%       364.210000
# 75%       521.570000
# max       699.930000
# Name: UnitPrice, dtype: float64

# %%
df['TotalPrice'].describe()
# Out:
# count    1200.000000
# mean     1053.968300
# std       819.856558
# min        11.390000
# 25%       410.520000
# 50%       823.615000
# 75%      1578.475000
# max      3456.400000
# Name: TotalPrice, dtype: float64

# %%
df.groupby('Product')['TotalPrice'].sum().sort_values(ascending=False)
# Out:
# Product
# Chair      195620.11
# Printer    195612.61
# Laptop     192126.56
# Tablet     186568.95
# Monitor    175651.41
# Desk       167459.93
# Phone      151722.39
# Name: TotalPrice, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#              Quantity  UnitPrice  ItemsInCart  TotalPrice
# Quantity     1.000000   0.014553     0.650061    0.615251
# UnitPrice    0.014553   1.000000     0.000602    0.717081
# ItemsInCart  0.650061   0.000602     1.000000    0.392540
# TotalPrice   0.615251   0.717081     0.392540    1.000000

# %%
df['Product'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
df['OrderStatus'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OrderStatus'>

# %%
df['PaymentMethod'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='PaymentMethod'>

# %%
df['ReferralSource'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ReferralSource'>

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Key Insights
#
# - The analysis identified the most frequently purchased products and their contribution to total sales.
# - Customer order statuses showed the overall distribution of completed, pending, cancelled, shipped, and returned orders.
# - The payment method analysis revealed customer preferences when completing purchases.
# - The correlation analysis helped identify relationships between numerical variables such as Quantity, UnitPrice, ItemsInCart, and TotalPrice.
# - The dataset showed useful patterns in customer purchasing behaviour that can support business decision-making.

# %% [markdown]
# ## Conclusion
#
# Exploratory Data Analysis (EDA) was performed to understand the structure, quality, and patterns within the dataset. The analysis included data quality checks, statistical summaries, categorical analysis, visualizations, and correlation analysis.
#
# The findings provide insights into customer orders, product performance, payment preferences, and sales patterns. The dataset is now ready for further analysis or business reporting.
